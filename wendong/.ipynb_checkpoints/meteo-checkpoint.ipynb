# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import datetime
import matplotlib.pyplot as plt


from shapely.geometry import Point

# %%
##Récupérer les données météo

# %%
tableau_stations_file = "../Data/Seine/Stations_2019.csv"
tableau_stations = gpd.read_file(tableau_stations_file, encoding='utf-8')

world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
cities = gpd.read_file(gpd.datasets.get_path('naturalearth_cities'))

# %%
tableau_stations['geometry'] = tableau_stations.apply(lambda x: Point(float(x['X (m)']), float(x['Y (m)'])), axis = 1)
tableau_stations = tableau_stations.set_crs('EPSG:27572')
tableau_stations = tableau_stations.to_crs(world.crs)
tableau_stations
# Out:
#    Code station                                    Libelle station  \
# 0      H0020010              La Seine à Quemigny-sur-Seine [Cosne]
# 1      H0100010                           La Seine à Nod-sur-Seine
# 2      H0100020                     La Seine à Plaines-Saint-Lange
# 3      H0400010                           La Seine à Bar-sur-Seine
# 4      H0400020                               La Seine à Courtenot
# 5      H0800011              La Seine [partielle] à Troyes [Foicy]
# 6      H0800012          La Seine [partielle] à Troyes [Tauxelles]
# 7      H0810010  La Seine à Méry-sur-Seine [après création gran...
# 8      H1700010                          La Seine à Pont-sur-Seine
# 9      H1940020    La Seine à Bazoches-lès-Bray [station ultrason]
# 10     H2900011      La Seine à Montereau-Fault-Yonne [station US]
# 11     H3930020  La Seine à Saint-Fargeau-Ponthierry [Sainte-As...
# 12     H4340020                             La Seine à Alfortville
# 13     H5920011  La Seine à Paris [Austerlitz avant création lacs]
# 14     H5920014  La Seine à Paris-13e__Arrondissement [pont d'A...
# 15     H8100020                                  La Seine à Vernon
# 16     H8100021                                  La Seine à Vernon
#
#      Regime influencé Altitude du zéro de l'échelle        Coordonnées  \
# 0   pas ou faiblement                        288.05  Lambert II Étendu
# 1   pas ou faiblement                        248.25  Lambert II Étendu
# 2   pas ou faiblement                        179.35  Lambert II Étendu
# 3   pas ou faiblement                           148  Lambert II Étendu
# 4   pas ou faiblement                             0  Lambert II Étendu
# 5           fortement                           102  Lambert II Étendu
# 6           fortement                           100  Lambert II Étendu
# 7           fortement                            78  Lambert II Étendu
# 8           fortement                            60  Lambert II Étendu
# 9           fortement                         52.59  Lambert II Étendu
# 10                                            45.77  Lambert II Étendu
# 11          fortement                         34.72  Lambert II Étendu
# 12  pas ou faiblement                         29.46  Lambert II Étendu
# 13          fortement                         25.92  Lambert II Étendu
# 14                                            25.92  Lambert II Étendu
# 15                                             9.16  Lambert II Étendu
# 16                                             9.16  Lambert II Étendu
#
#      X (m)    Y (m)                  geometry
# 0   775157  2300217  POINT (4.66954 47.67808)
# 1   767439  2309604  POINT (4.57034 47.76448)
# 2   760029  2335130  POINT (4.48082 47.99581)
# 3   751916  2348365  POINT (4.37676 48.11672)
# 4   746950  2351620  POINT (4.31119 48.14712)
# 5   731065  2368493  POINT (4.10290 48.30219)
# 6   729271  2369769  POINT (4.07911 48.31402)
# 7   714764  2390999  POINT (3.88926 48.50758)
# 8   692920  2392352  POINT (3.59406 48.52325)
# 9   663190  2381000  POINT (3.19008 48.42479)
# 10  646210  2376785  POINT (2.96027 48.38833)
# 11  615835  2393175  POINT (2.55086 48.53713)
# 12  605979  2420343  POINT (2.41782 48.78150)
# 13  602142  2427451  POINT (2.36567 48.84541)
# 14  602130  2427440  POINT (2.36551 48.84531)
# 15  538060  2455707  POINT (1.48894 49.09633)
# 16  538060  2455707  POINT (1.48894 49.09633)

# %%
data= pd.read_csv("https://power.larc.nasa.gov/api/temporal/hourly/point?Time=LST&parameters=T2M,T2MDEW,T2MWET,QV2M,RH2M,PRECTOTCORR&community=AG&longitude=4.6695&latitude=47.6781&start=20010101&end=20201231&format=CSV", skiprows=14,encoding='utf8')
data

# %%
'''Parameter(s):
T2M             MERRA-2 Temperature at 2 Meters (C) 
T2MDEW          MERRA-2 Dew/Frost Point at 2 Meters (C)
T2MWET          MERRA-2 Wet Bulb Temperature at 2 Meters (C) 
QV2M            MERRA-2 Specific Humidity at 2 Meters (g/kg) 
RH2M            MERRA-2 Relative Humidity at 2 Meters (%) 
PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/hour) '''

# %%
tableau_stations['lon'] = tableau_stations.geometry.apply(lambda p: p.x)
tableau_stations['lat'] = tableau_stations.geometry.apply(lambda p: p.y)
tableau_stations

# %%
https://power.larc.nasa.gov/api/temporal/hourly/point?Time=LST&parameters=T2M,T2MDEW,T2MWET,QV2M,RH2M,PRECTOTCORR&community=AG&longitude=4.6695&latitude=47.6781&start=20010101&end=20201231&format=CSV

# %%
for i in range(tableau_stations.shape[0]):
    lon=tableau_stations["lon"][i]
    lat=tableau_stations["lat"][i]
    name=tableau_stations["Code station"][i]
    data = pd.read_csv("https://power.larc.nasa.gov/api/temporal/hourly/point?Time=LST&parameters=T2M,T2MDEW,T2MWET,QV2M,RH2M,PRECTOTCORR&community=AG&longitude={}&latitude={}&start=20010101&end=20201231&format=CSV".format(lon,lat),skiprows=14)
    data.to_csv(str(name)+".csv", index = False, header = True)

# %%
for i in range(tableau_stations.shape[0]):

# %%
data= pd.read_csv("https://nrfaapps.ceh.ac.uk/nrfa/ws/time-series?format=nrfa-csv&data-type=cdr&station=45001")
data
