# %% [markdown]
# On prend le problème de prédiction du débit moyen journalier à une semaine, le critère que l'on va minimiser est un mean square error sur toutes les stations. (discuter)
#
# On choisis de faire de la validation croisée pour faire de la sélection de modèle, et on garde une ensemble de test.
# On a des données de 2010 à 2020 (11 années).
# On garde 2020 comme ensemble de test, et on fait 10 ensembles de validation croisée, on entraine sur 2 années consécutives et on valide sur 1 année, ca permet de faire en sorte que chaque année soit utilisée une fois, et chaque

# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import datetime
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import ListedColormap
from scipy import signal
from scipy import stats
from tqdm import tqdm
from shapely.wkt import loads
from shapely.geometry import Point
from statsmodels.tsa.stattools import acf, pacf

# %%
stations_debit = pd.read_csv("../Data/Base/Stations_Debit.csv")
stations_meteo = pd.read_csv("../Data/Base/Stations_Meteo.csv")
mesures = pd.read_csv("../Data/Base/Mesures.csv")
mesures["Date"] = pd.to_datetime(mesures["Date"], format = "%Y/%m/%d %H:%M:%S")

# %%
mesures
# Out:
#                      Date  O0200020  O2620010  O6140010  O9000010  K0030020  \
# 0     2010-01-01 00:00:00      41.3     122.0     285.0     506.0      0.42
# 1     2010-01-01 02:00:00      47.4     125.0     291.0     520.0      0.44
# 2     2010-01-01 04:00:00      49.2     132.0     300.0     516.0      0.50
# 3     2010-01-01 06:00:00      42.4     135.0     314.0     496.0      0.54
# 4     2010-01-01 08:00:00      47.3     132.0     329.0     472.0      0.54
# ...                   ...       ...       ...       ...       ...       ...
# 48211 2020-12-31 14:00:00      42.3     319.0     865.0    2010.0      0.75
# 48212 2020-12-31 16:00:00      45.7     311.0    1080.0    2000.0      0.75
# 48213 2020-12-31 18:00:00      48.6     301.0    1020.0    1950.0      0.75
# 48214 2020-12-31 20:00:00      48.9     292.0     967.0    1910.0      0.75
# 48215 2020-12-31 22:00:00      47.0     284.0     934.0    1920.0      0.75
#
#        K0100020  K0260020  K0550010  K0690010  ...  Vitesse_vent_07747  \
# 0          2.87      9.33      22.8      6.90  ...            7.733333
# 1          2.86      9.93      21.6      7.01  ...            7.733333
# 2          2.84     10.80      21.9      7.03  ...           11.800000
# 3          2.90     10.20      20.8      7.04  ...            9.066667
# 4          3.04     10.70      21.4      7.12  ...            9.066667
# ...         ...       ...       ...       ...  ...                 ...
# 48211      2.94     11.70      34.0     27.50  ...            2.066667
# 48212      2.94     11.60      33.7     43.10  ...            2.600000
# 48213      2.96     11.60      31.7     34.80  ...            2.400000
# 48214      2.98     11.50      33.1     37.20  ...            2.433333
# 48215      3.00     11.50      33.4     58.00  ...            2.700000
#
#        Temperature_07747  Humidite_07747  Precipitations_07747  \
# 0              10.333333       71.000000              0.133333
# 1              10.333333       71.000000              0.133333
# 2              10.000000       61.000000              0.000000
# 3              10.533333       50.333333              0.000000
# 4              11.200000       43.000000              0.000000
# ...                  ...             ...                   ...
# 48211          12.600000       40.666667              0.000000
# 48212          12.400000       48.000000              0.000000
# 48213           9.800000       55.333333              0.000000
# 48214           7.566667       63.666667              0.000000
# 48215           5.700000       73.000000              0.000000
#
#        Pression_07761  Direction_vent_07761  Vitesse_vent_07761  \
# 0        99393.333333            206.666667            8.400000
# 1        99393.333333            206.666667            8.400000
# 2        99180.000000            220.000000            9.800000
# 3        99193.333333            240.000000            6.666667
# 4        99253.333333            253.333333            9.066667
# ...               ...                   ...                 ...
# 48211   101170.000000             43.333333            1.700000
# 48212   101130.000000             30.000000            1.300000
# 48213   101143.333333             36.666667            2.366667
# 48214   101130.000000             43.333333            2.933333
# 48215   101090.000000             50.000000            3.000000
#
#        Temperature_07761  Humidite_07761  Precipitations_07761
# 0              14.233333       90.000000              0.000000
# 1              14.233333       90.000000              0.000000
# 2              14.300000       90.000000              0.000000
# 3              12.900000       78.000000              0.533333
# 4              11.800000       74.666667              0.666667
# ...                  ...             ...                   ...
# 48211          10.533333       76.333333             -0.033333
# 48212          10.200000       79.000000             -0.100000
# 48213           8.466667       84.333333             -0.033333
# 48214           7.666667       86.666667              0.200000
# 48215           7.800000       86.000000              0.600000
#
# [48216 rows x 243 columns]
